# %% [markdown]
# # FIFA World Cup Analysis

# %% [markdown]
# The FIFA World Cup, often simply called the World Cup, is an international association football competition contested by the senior men's national teams of the members of the Fédération Internationale de Football Association (FIFA), the sport's global governing body. The championship has been awarded every four years since the inaugural tournament in 1930, except in 1942 and 1946 when it was not held because of the Second World War. The current champion is Germany, which won its fourth title at the 2014 tournament in Brazil.

# %% [markdown]
# # Content
#
# 1. Data Cleaning
#
# 2. Visualization
#
# i. Most Number of World Cup Winning Title
#
# ii. Number of Goal Per Countary
#
# iii. Attendance, Number of Teams, Goals, and Matches per Cup
#
# iv. Goals Per Team Per World Cup
#
# v. Matches With Heihest Number Of Attendance
#
# vi. Stadium with Highest Average Attendance
#
# vii. Which countries had won the cup ?
#
# viii. Number of goal per country
#
# ix. Match outcome by home and away temas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly as py
import cufflinks as cf

# %%
players = pd.read_csv('/content/sample_data/WorldCupPlayers.csv')
players.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %%
matches = pd.read_csv('/content/sample_data/WorldCupMatches.csv')
matches.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
world_cup = pd.read_csv('/content/sample_data/WorldCups.csv')
world_cup.head()
# Out:
#    Year      Country      Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay     Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy       Italy  Czechoslovakia  Germany     Austria
# 2  1938       France       Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil     Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany FR         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18    590.549
# 1           70              16             17    363.000
# 2           84              15             18    375.700
# 3           88              13             22  1.045.246
# 4          140              16             26    768.607

# %% [markdown]
# # Data Cleaning

# %%
matches.dropna(subset=['Year'], inplace=True)

# %%
matches.tail()
# Out:
#        Year              Datetime                     Stage  \
# 847  2014.0  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 849  2014.0  09 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014.0  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 847     Arena Fonte Nova        Salvador     Netherlands              0.0
# 848     Estadio Mineirao  Belo Horizonte          Brazil              1.0
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands              0.0
# 850     Estadio Nacional        Brasilia          Brazil              0.0
# 851  Estadio do Maracana  Rio De Janeiro         Germany              1.0
#
#      Away Team Goals Away Team Name                         Win conditions  \
# 847              0.0     Costa Rica  Netherlands win on penalties (4 - 3)
# ...

# %%
matches['Home Team Name'].value_counts()
# Out:
# Home Team Name
# Brazil                        82
# Italy                         57
# Argentina                     54
# Germany FR                    43
# England                       35
#                               ..
# Wales                          1
# Norway                         1
# rn">United Arab Emirates       1
# Haiti                          1
# rn">Bosnia and Herzegovina     1
# Name: count, Length: 78, dtype: int64

# %%
names = matches[matches['Home Team Name'].str.contains('rn">', na=False)]['Home Team Name'].value_counts()
names
# Out:
# Home Team Name
# rn">Republic of Ireland       5
# rn">United Arab Emirates      1
# rn">Trinidad and Tobago       1
# rn">Serbia and Montenegro     1
# rn">Bosnia and Herzegovina    1
# Name: count, dtype: int64

# %%
wrong = list(names.index)
wrong
# Out:
# ['rn">Republic of Ireland',
#  'rn">United Arab Emirates',
#  'rn">Trinidad and Tobago',
#  'rn">Serbia and Montenegro',
#  'rn">Bosnia and Herzegovina']

# %%
correct = [name.split('>')[1] for name in wrong]
correct
# Out:
# ['Republic of Ireland',
#  'United Arab Emirates',
#  'Trinidad and Tobago',
#  'Serbia and Montenegro',
#  'Bosnia and Herzegovina']

# %%
old_name = ['Germany FR', 'Maracan� - Est�dio Jornalista M�rio Filho', 'Estadio do Maracana']
new_name = ['Germany', 'Maracan Stadium', 'Maracan Stadium']

# %%
wrong = wrong + old_name
correct = correct + new_name

# %%
wrong, correct
# Out:
# (['rn">Republic of Ireland',
#   'rn">United Arab Emirates',
#   'rn">Trinidad and Tobago',
#   'rn">Serbia and Montenegro',
#   'rn">Bosnia and Herzegovina',
#   'Germany FR',
#   'Maracan� - Est�dio Jornalista M�rio Filho',
#   'Estadio do Maracana'],
#  ['Republic of Ireland',
#   'United Arab Emirates',
#   'Trinidad and Tobago',
#   'Serbia and Montenegro',
#   'Bosnia and Herzegovina',
#   'Germany',
#   'Maracan Stadium',
#   'Maracan Stadium'])

# %%
for index, wr in enumerate(wrong):
    world_cup = world_cup.replace(wrong[index], correct[index])

for index, wr in enumerate(wrong):
    matches = matches.replace(wrong[index], correct[index])

for index, wr in enumerate(wrong):
    players = players.replace(wrong[index], correct[index])

# %%
names = matches[matches['Home Team Name'].str.contains('rn">', na=False)]['Home Team Name'].value_counts()
names
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# # Most Number of World Cup Winning Title

# %%
winner = world_cup['Winner'].value_counts()
winner
# Out:
# Winner
# Brazil       5
# Italy        4
# Germany      4
# Uruguay      2
# Argentina    2
# England      1
# France       1
# Spain        1
# Name: count, dtype: int64

# %%
runnerup = world_cup['Runners-Up'].value_counts()
runnerup
# Out:
# Runners-Up
# Germany           4
# Argentina         3
# Netherlands       3
# Czechoslovakia    2
# Hungary           2
# Brazil            2
# Italy             2
# Sweden            1
# France            1
# Name: count, dtype: int64

# %%
third = world_cup['Third'].value_counts()
third
# Out:
# Third
# Germany        4
# Brazil         2
# Sweden         2
# France         2
# Poland         2
# USA            1
# Austria        1
# Chile          1
# Portugal       1
# Italy          1
# Croatia        1
# Turkey         1
# Netherlands    1
# Name: count, dtype: int64

# %%
teams = pd.concat([winner, runnerup, third], axis=1)
teams.fillna(0, inplace=True)
teams = teams.astype(int)

# Using rename method
teams.rename(columns={0: 'Winner', 1: 'Runner-up', 2: 'Third'}, inplace=True)

# OR using columns attribute directly
teams.columns = ['winner', 'runnerup', 'third']

# Display the updated DataFrame
teams
# Out:
#                 winner  runnerup  third
# Brazil               5         2      2
# Italy                4         2      1
# Germany              4         4      4
# Uruguay              2         0      0
# Argentina            2         3      0
# England              1         0      0
# France               1         1      2
# Spain                1         0      0
# Netherlands          0         3      1
# Czechoslovakia       0         2      0
# Hungary              0         2      0
# Sweden               0         1      2
# Poland               0         0      2
# USA                  0         0      1
# Austria              0         0      1
# Chile                0         0      1
# Portugal             0         0      1
# Croatia              0         0      1
# Turkey               0         0      1

# %%
# Assuming teams is a DataFrame with 'Teams' as index and 'Count' as a column

plt.figure(figsize=(14, 6))
teams.plot(kind='bar')

plt.xlabel('Teams')
plt.ylabel('Count')
plt.title('FIFA World Cup Winning Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Number of Goal Per Countary

# %%
matches.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
home = matches[['Home Team Name', 'Home Team Goals']].dropna()
away = matches[['Away Team Name', 'Away Team Goals']].dropna()

# %%
home.columns = ['Countries', 'Goals']
away.columns = home.columns

# %%
# Append DataFrames using pd.concat
goals = pd.concat([home, away], ignore_index=True)

# Display the resulting DataFrame
goals
# Out:
#         Countries  Goals
# 0          France    4.0
# 1             USA    3.0
# 2      Yugoslavia    2.0
# 3         Romania    3.0
# 4       Argentina    1.0
# ...           ...    ...
# 1699   Costa Rica    0.0
# 1700      Germany    7.0
# 1701    Argentina    0.0
# 1702  Netherlands    3.0
# 1703    Argentina    0.0
#
# [1704 rows x 2 columns]

# %%
goals = goals.groupby('Countries').sum()
goals
# Out:
#                       Goals
# Countries
# Algeria                14.0
# Angola                  1.0
# Argentina             133.0
# Australia              11.0
# Austria                43.0
# ...                     ...
# United Arab Emirates    2.0
# Uruguay                80.0
# Wales                   4.0
# Yugoslavia             60.0
# Zaire                   0.0
#
# [82 rows x 1 columns]

# %%
goals = goals.sort_values(by = 'Goals', ascending=False)
goals
# Out:
#                      Goals
# Countries
# Germany              235.0
# Brazil               225.0
# Argentina            133.0
# Italy                128.0
# France               108.0
# ...                    ...
# Trinidad and Tobago    0.0
# Canada                 0.0
# China PR               0.0
# Dutch East Indies      0.0
# Zaire                  0.0
#
# [82 rows x 1 columns]

# %%
# Assuming goals is a DataFrame and has relevant columns for 'Country Names' and 'Goals'
plt.figure(figsize=(10, 6))
sns.barplot(x='Countries', y='Goals', data=goals[:20])

plt.xlabel('Country Names')
plt.ylabel('Goals')
plt.title('Countries Hits Number of Goals')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Attendance, Number of Teams, Goals, and Matches per Cup

# %%
world_cup['Attendance'] = world_cup['Attendance'].str.replace(".", "")

# %%
world_cup.head()
# Out:
#    Year      Country   Winner      Runners-Up    Third      Fourth  \
# 0  1930      Uruguay  Uruguay       Argentina      USA  Yugoslavia
# 1  1934        Italy    Italy  Czechoslovakia  Germany     Austria
# 2  1938       France    Italy         Hungary   Brazil      Sweden
# 3  1950       Brazil  Uruguay          Brazil   Sweden       Spain
# 4  1954  Switzerland  Germany         Hungary  Austria     Uruguay
#
#    GoalsScored  QualifiedTeams  MatchesPlayed Attendance
# 0           70              13             18     590549
# 1           70              16             17     363000
# 2           84              15             18     375700
# 3           88              13             22    1045246
# 4          140              16             26     768607

# %%
fig, ax = plt.subplots(figsize = (10,5))
sns.despine(right = True)
g = sns.barplot(x = 'Year', y = 'Attendance', data = world_cup)
g.set_xticklabels(g.get_xticklabels(), rotation = 80)
g.set_title('Attendance Per Year')
# Out:
# <ipython-input-30-68d73a196cde>:4: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
# Text(0.5, 1.0, 'Attendance Per Year')

# %%
fig, ax = plt.subplots(figsize = (10,5))
sns.despine(right = True)
g = sns.barplot(x = 'Year', y = 'QualifiedTeams', data = world_cup)
g.set_xticklabels(g.get_xticklabels(), rotation = 80)
g.set_title('Qualified Teams Per Year')
# Out:
# <ipython-input-31-6d1eedd253dd>:4: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
# Text(0.5, 1.0, 'Qualified Teams Per Year')

# %%
fig, ax = plt.subplots(figsize = (10,5))
sns.despine(right = True)
g = sns.barplot(x = 'Year', y = 'GoalsScored', data = world_cup)
g.set_xticklabels(g.get_xticklabels(), rotation = 80)
g.set_title('Goals Scored by Teams Per Year')
# Out:
# <ipython-input-32-1f3d3975c1df>:4: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
# Text(0.5, 1.0, 'Goals Scored by Teams Per Year')

# %%
fig, ax = plt.subplots(figsize = (10,5))
sns.despine(right = True)
g = sns.barplot(x = 'Year', y = 'MatchesPlayed', data = world_cup)
g.set_xticklabels(g.get_xticklabels(), rotation = 80)
g.set_title('Matches Plyed Scored by Teams Per Year')
# Out:
# <ipython-input-33-a25dde6371b5>:4: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
# Text(0.5, 1.0, 'Matches Plyed Scored by Teams Per Year')

# %% [markdown]
# # Goals Per Team Per World Cup

# %%
matches.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
home = matches.groupby(['Year', 'Home Team Name'])['Home Team Goals'].sum()
home
# Out:
# Year    Home Team Name
# 1930.0  Argentina         16.0
#         Brazil             4.0
#         Chile              4.0
#         France             4.0
#         Paraguay           1.0
#                           ...
# 2014.0  Russia             1.0
#         Spain              1.0
#         Switzerland        4.0
#         USA                2.0
#         Uruguay            3.0
# Name: Home Team Goals, Length: 366, dtype: float64

# %%
away = matches.groupby(['Year', 'Away Team Name'])['Away Team Goals'].sum()
away
# Out:
# Year    Away Team Name
# 1930.0  Argentina         2.0
#         Belgium           0.0
#         Bolivia           0.0
#         Brazil            1.0
#         Chile             1.0
#                          ...
# 2014.0  Russia            1.0
#         Spain             3.0
#         Switzerland       3.0
#         USA               4.0
#         Uruguay           1.0
# Name: Away Team Goals, Length: 411, dtype: float64

# %%
goals = pd.concat([home, away], axis=1)
goals.fillna(0, inplace=True)
goals['Goals'] = goals['Home Team Goals'] + goals['Away Team Goals']
goals = goals.drop(labels = ['Home Team Goals', 'Away Team Goals'], axis = 1)
goals
# Out:
#                   Goals
# Year
# 1930.0 Argentina   18.0
#        Brazil       5.0
#        Chile        5.0
#        France       4.0
#        Paraguay     1.0
# ...                 ...
# 1998.0 Iran         2.0
#        Mexico       8.0
#        Norway       5.0
#        Tunisia      1.0
# 2006.0 IR Iran      0.0
#
# [427 rows x 1 columns]

# %%
goals = goals.reset_index()

# %%
goals = goals.sort_values(by = ['Year', 'Goals'], ascending = [True,False])
#goals.rename(columns = {level_1:'Country'})

# %%
top5 = goals.groupby('Year').head()
top5.head(10)
# Out:
#       Year         level_1  Goals
# 0   1930.0       Argentina   18.0
# 7   1930.0         Uruguay   15.0
# 6   1930.0             USA    7.0
# 8   1930.0      Yugoslavia    7.0
# 1   1930.0          Brazil    5.0
# 13  1934.0           Italy   12.0
# 11  1934.0         Germany   11.0
# 10  1934.0  Czechoslovakia    9.0
# 9   1934.0         Austria    7.0
# 12  1934.0         Hungary    5.0

# %%
import plotly.graph_objects as go

# %%
x, y = goals['Year'].values, goals['Goals'].values

# %%
# Assuming 'top5' is your DataFrame

plt.figure(figsize=(16, 8))

# Plot using Seaborn
sns.barplot(data=top5, x='Year', y='Goals', hue='level_1', estimator=sum, errorbar=None)

plt.title('Top 5 Teams with most Goals')
plt.xlabel('Year')
plt.ylabel('Goals')
plt.legend(title='Country')
plt.show()

# %% [markdown]
# # Matches With Highest Number Of Attendance

# %%
top10 = matches.sort_values(by='Attendance', ascending=False)[:10]
top10['vs'] = top10['Home Team Name'] + " vs " + top10['Away Team Name']

plt.figure(figsize=(12, 10))

ax = sns.barplot(y=top10['vs'], x=top10['Attendance'], palette='viridis')
sns.despine(right=True)
plt.ylabel('Match Teams')
plt.xlabel('Attendance')
plt.title('Matches with the highest number of Attendance')

for i, s in enumerate("Stadium: " + top10['Stadium'] + ", Date: " + top10['Datetime']):
    ax.text(2000, i, s, fontsize=12, color='white')

plt.show()
# Out:
# <ipython-input-44-d8e5786c3dbd>:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # Stadium with Highest Average Attendance

# %%
matches['Year'] = matches['Year'].astype(int)

std = matches.groupby(['Stadium', 'City'])['Attendance'].mean().reset_index().sort_values(by='Attendance', ascending=False)

top10 = std[:10]

plt.figure(figsize=(12, 9))
ax = sns.barplot(y=top10['Stadium'], x=top10['Attendance'], palette='magma')
sns.despine(right=True)

plt.ylabel('Stadium Names')
plt.xlabel('Attendance')
plt.title('Stadium with the highest number of attendance')

for i, s in enumerate("City: " + top10['City']):
    ax.text(2000, i, s, fontsize=12, color='w')

plt.show()
# Out:
# <ipython-input-45-bd9febfcb564>:8: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %%
city_counts = matches['City'].value_counts()[:20]

plt.figure(figsize=(10, 6))
city_counts.plot(kind='bar', color='skyblue')  # Use any color you prefer
plt.xlabel('City')
plt.ylabel('Number of Matches')
plt.title('Top 20 Cities by Number of Matches')
plt.xticks(rotation=80)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Which countries had won the cup ?

# %%
gold = world_cup["Winner"]
silver = world_cup["Runners-Up"]
bronze = world_cup["Third"]

# %%
gold_count = pd.DataFrame.from_dict(gold.value_counts())
silver_count = pd.DataFrame.from_dict(silver.value_counts())
bronze_count = pd.DataFrame.from_dict(bronze.value_counts())

# Joining counts
podium_count = pd.concat([gold_count, silver_count, bronze_count], axis=1, join='outer')
podium_count = podium_count.fillna(0).astype('int64')

# Renaming columns
podium_count.columns = ['WINNER', 'SECOND', 'THIRD']

# Sorting by podium counts
podium_count = podium_count.sort_values(by=['WINNER', 'SECOND', 'THIRD'], ascending=False)

# %%
podium_count.plot(y=['WINNER', 'SECOND', 'THIRD'], kind="bar",
                  color =['gold','silver','brown'], figsize=(15, 6), fontsize=14,
                 width=0.8, align='center')
plt.xlabel('Countries')
plt.ylabel('Number of podium')
plt.title('Number of podium by country')
# Out:
# Text(0.5, 1.0, 'Number of podium by country')

# %% [markdown]
# # Number of goal per country

# %%
# Handling with null values
home = matches[['Home Team Name', 'Home Team Goals']].dropna()
away = matches[['Away Team Name', 'Away Team Goals']].dropna()

# %%
# Initialize the DataFrame
goal_per_country = pd.DataFrame(columns=['countries', 'goals'])

# Rename columns and append to the DataFrame
home_renamed = home.rename(columns={'Home Team Name': 'countries', 'Home Team Goals': 'goals'})
goal_per_country = pd.concat([goal_per_country, home_renamed[['countries', 'goals']]])

away_renamed = away.rename(columns={'Away Team Name': 'countries', 'Away Team Goals': 'goals'})
goal_per_country = pd.concat([goal_per_country, away_renamed[['countries', 'goals']]])

# Convert the 'goals' column to integer
goal_per_country['goals'] = goal_per_country['goals'].astype('int64')

# Group by 'countries' and sum the 'goals', then sort
goal_per_country = goal_per_country.groupby('countries')['goals'].sum().sort_values(ascending=False)

# %%
# Plot the top 10 countries
top_10_countries = goal_per_country.head(10)
top_10_countries.plot(kind='bar', figsize=(12, 6), fontsize=14, color = 'g')
plt.xlabel('Countries')
plt.ylabel('Total Goals')
plt.title('Top 10 Countries by Goals')
plt.show()

# %% [markdown]
# # Match outcome by home and away temas

# %%
def get_labels(matches):
    if matches['Home Team Goals'] > matches['Away Team Goals']:
        return 'Home Team Win'
    if matches['Home Team Goals'] < matches['Away Team Goals']:
        return 'Away Team Win'
    return 'DRAW'

# %%
matches['outcome'] = matches.apply(lambda x: get_labels(x), axis=1)

# %%
matches.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  ...  Half-time Home Goals  Half-time Away Goals  \
# 0                 ...                   3.0                   0.0
# ...

# %%
mt = matches['outcome'].value_counts()
mt
# Out:
# outcome
# Home Team Win    488
# DRAW             190
# Away Team Win    174
# Name: count, dtype: int64

# %%
plt.figure(figsize = (6,6))

mt.plot.pie(autopct = "%1.2f%%", colors = sns.color_palette('winter_r'), shadow = True)

c = plt.Circle((0,0), 0.4, color =  'white')
plt.gca().add_artist(c)
plt.title('Match Outcomes by Home and Away Teams')
plt.show()

# %% [markdown]
# # ***Thanks you**
